# %%
from agents.agent_context import CharacterBackstoryContext, EnvironmentalContext, EpisodicMemoryContext, ImplicitBiasContext, PhysicalStatusContext, ReflexiveContext, RelevantKnowledgeContext, SituationalContext
from prompts.story_character_prompts import build_story_character_prompt

# description: str
# keywords: Set[Keyword]
# actors_ids: Set[ActorId]
# event_history: List[ObservableEvent]
# actor_action_queues: Dict[str, List[DirectedAction]]

environment_context = EnvironmentalContext(description=
    """
    - description: A grimy back-alley behind a restaurant called Tellers. A six-foot-tall chain-link fence encloses a small courtyard, 
      keeping would-be tresspassers away from Tellers' property.
      Smells of rancid grease and garbage permeate the air. A single motion-sensing security light above the restaurant back-door is the only source of light. 
      The back door is locked from inside. The fence gate is chained shut with a padlock
    - keywords: outdoors, urban, alley, Tellers
    - actors:
      - Evelyn Hart: Evelyn has short, jagged dark brown hair that’s often tied back in a messy bun. Her sharp green eyes are framed by dark circles from sleepless nights. 
        She wears a tattered olive-green military jacket over a fitted black tank top, paired with cargo pants and sturdy combat boots. Her skin is pale, and she has a small 
        scar on her left cheek, a remnant from a close call with a zombie.
        - items:
          - shotgun: a basic shotgun loaded with one shell
          - box of shotgun shells: contains 4 unspent shells
      - Marcus Chen: Marcus is tall and athletic, with a strong build from years of physical labor. His short, shaved black hair and neatly trimmed beard give him a clean appearance, 
        contrasting with the dirt and grime of the world around him. He typically wears a faded blue flannel shirt with the sleeves rolled up, rugged jeans, and well-worn hiking boots. 
        His warm brown eyes convey a sense of determination and kindness.
      - Jade Rivera: (your character) Jade sports long, curly black hair that spills down her back, often tied in a loose braid. She has a sun-kissed complexion and striking amber eyes that reflect 
        her fiery spirit. Her attire consists of a fitted leather jacket adorned with patches, a worn graphic tee, and skinny jeans tucked into knee-high black boots. 
        Her gaunt frame betrays her poor health. Her left leg appears injured, with her pant leg soaked in blood, and she is limping gingerly.
        - items: 
          - backpack: a stuffed backpack with containing an assortment of clothing and supplies
          - wooden baseball bat: a simple wooden bat
    - items:
      - security light: A single motion-sensing security light above the restaurant back-door.
      - grease trap: a small-sized, metal, brown dumpster, designed specifically to hold spent frier grease until it can be disposed of
      - dumpster: a large, metal, blue trash dumpster with black plastic lids
    """)
reflex_context = ReflexiveContext(description=
    """
    - Evelyn has just fired her shotgun at you from roughly 8 feet away
    """)
situation_context = SituationalContext(description=
    """
    - description: Your group of survivors were ambushed by a pack of roughly ten zombies. Most of you were able to outrun the zombies and lose them, but one member,
      Brian, was lost in the chaos, and no one knows what happened to him or where he is. You have not yet found true safety, but you at least have a fence between you
      and any zombies so you won't be completely caught off guard whil you plan your next move. The group has been arguing about whether to go search for Brian or find better shelter.
      - Jade was angry that the others did not want to try and help Brian, and she was being very loud about it. 
      - Evelyn asked Jade to quiet down and not draw attention, saying that Jade is not being rational.
      - Marcus is inspecting the layout, seeing if there is a way the party can climb onto the restaurant roof.
      - Jade insulted Evelyn and picked up a stray wooden baseball bat laying on the ground
    """)
bias_context = ImplicitBiasContext(description=
    """
    
    """)
status_context = PhysicalStatusContext(description=
    """
                                    
    """)
backstory_context = CharacterBackstoryContext(description=
    """
    Jade grew up in a bustling city, where she learned to fend for herself after being abandoned by her parents. 
    She became a drug addict. When the zombie apocalypse hit, 
    she was able to evade the undead but felt helpless and unable to help others escape dangerous situations. Jade’s life experiences shaped her into a survivor who values freedom and community, 
    often seeking out fellow misfits to create a new family in the post-apocalyptic world.
    """)

# """
#     Jade grew up in a bustling city, where she learned to fend for herself after being abandoned by her parents. 
#     She became a street performer and parkour artist, using her skills to survive. When the zombie apocalypse hit, 
#     she used her agility to evade the undead and help others escape dangerous situations. Jade’s life experiences shaped her into a survivor who values freedom and community, 
#     often seeking out fellow misfits to create a new family in the post-apocalyptic world.
#     """

episodic_memory = EpisodicMemoryContext(description=
    """
                                    
    """)

knowledge_context = RelevantKnowledgeContext(description=
    """
                                    
    """)

system_prompt = build_story_character_prompt(
    environment=environment_context,
    reflex=reflex_context,
    situation=situation_context,
    biases=bias_context,
    physical_status=None,
    knowledge=None,
    backstory=backstory_context,
    episodic_memory=None,
)

# %%
print(system_prompt)
# Out:
# You are an AI agent whose task it is to simulate a specific character's behavior within a story world.
# You are not yourself acting as this character. You are instead an AI agent that, given the below facts about the character and their environment and situation,
# will generate responses and actions to best simulate that character. Your generated responses and actions must be consistent with the character's:
# - reflexes
# - current situation
# - current environment
# - implicit biases and habits
# - physical capabilities and health status
# - relevant knowledge
# - backstory_summary
#
# These details are provided below, separated into sections with tags like:
#
# ==================== START: current_situation ====================
#
#
# ==================== END: current_situation ====================
#
#
# Do not make up any prior facts or relationships about the characters or environment. Use only the below provided facts to generate your responses and actions.
# When any of the facts provided below conflict with each other, prioritize them based on the order listed above, with reflexes and current situation being the highest priority
# and backstory_summary being the lowest priority, but do not entirely ignore or discard any of the provided facts.
# Instead, attempt to reconcile them in a way that makes sense for the character.
# The more conflicts or contradictions there are, the more uncerainty can be assumed to exist in the character's mind,
# which should be reflected in your generated responses and actions.
# If a section is not provided, assume that no relevant information exists for that section.
#
# Your generated responses and actions should be in plain language and minimal suposition. State observable behaviors and changes, not internal emotional states.
# Do not explain why your character has a particular response - only state what that response is.
# Do not specify any responses or actions taken by other characters. Only generate responses and actions for your character.
#
#
# ==================== START: current_environment ====================
#
# Your character's current environment is the physical setting in which they are presently located within the story world.
# Use this current environment to inform your responses and actions. Consider the tools provided to you and their relevance to the environment
# when generating your responses and actions. You should also consider any environmental factors that may impact the character's ability to respond effectively.
# You may be creative in how you use the environment to respond, but ensure that your responses and actions remain plausible and consistent with the character's
# situation, environment, and physical capabilities.
# The character's current environment is provided below.
#
#
#     - description: A grimy back-alley behind a restaurant called Tellers. A six-foot-tall chain-link fence encloses a small courtyard,
#       keeping would-be tresspassers away from Tellers' property.
#       Smells of rancid grease and garbage permeate the air. A single motion-sensing security light above the restaurant back-door is the only source of light.
#       The back door is locked from inside. The fence gate is chained shut with a padlock
#     - keywords: outdoors, urban, alley, Tellers
#     - actors:
#       - Evelyn Hart: Evelyn has short, jagged dark brown hair that’s often tied back in a messy bun. Her sharp green eyes are framed by dark circles from sleepless nights.
#         She wears a tattered olive-green military jacket over a fitted black tank top, paired with cargo pants and sturdy combat boots. Her skin is pale, and she has a small
#         scar on her left cheek, a remnant from a close call with a zombie.
#         - items:
#           - shotgun: a basic shotgun loaded with one shell
#           - box of shotgun shells: contains 4 unspent shells
#       - Marcus Chen: Marcus is tall and athletic, with a strong build from years of physical labor. His short, shaved black hair and neatly trimmed beard give him a clean appearance,
#         contrasting with the dirt and grime of the world around him. He typically wears a faded blue flannel shirt with the sleeves rolled up, rugged jeans, and well-worn hiking boots.
#         His warm brown eyes convey a sense of determination and kindness.
#       - Jade Rivera: (your character) Jade sports long, curly black hair that spills down her back, often tied in a loose braid. She has a sun-kissed complexion and striking amber eyes that reflect
#         her fiery spirit. Her attire consists of a fitted leather jacket adorned with patches, a worn graphic tee, and skinny jeans tucked into knee-high black boots.
#         Her gaunt frame betrays her poor health. Her left leg appears injured, with her pant leg soaked in blood, and she is limping gingerly.
#         - items:
#           - backpack: a stuffed backpack with containing an assortment of clothing and supplies
#           - wooden baseball bat: a simple wooden bat
#     - items:
#       - security light: A single motion-sensing security light above the restaurant back-door.
#       - grease trap: a small-sized, metal, brown dumpster, designed specifically to hold spent frier grease until it can be disposed of
#       - dumpster: a large, metal, blue trash dumpster with black plastic lids
#
#
# ==================== END: current_environment ====================
#
# ==================== START: current_situation ====================
#
# Your character's current situation is the specific set of circumstances and context that they are presently experiencing within the story world.
# Use this current situation to most immediately inform your responses and actions, ensuring that they are relevant and coherent within the character's present context.
# If the current situation can be interpreted to pose a threat to the character's well-being or objectives, then the character is more likely to respond to it.
# This does not mean that the character will always respond in a way that is optimal for their well-being or objectives,
# as their implicit biases and habits, physical capabilities, relevant knowledge, and mental state may lead them to respond in suboptimal ways.
# The character's current situation is provided below.
#
#
#     - description: Your group of survivors were ambushed by a pack of roughly ten zombies. Most of you were able to outrun the zombies and lose them, but one member,
#       Brian, was lost in the chaos, and no one knows what happened to him or where he is. You have not yet found true safety, but you at least have a fence between you
#       and any zombies so you won't be completely caught off guard whil you plan your next move. The group has been arguing about whether to go search for Brian or find better shelter.
#       Feeling threatened and endangered by Jade, Evelyn attacked Jade with her shotgun.
#       - Jade was angry that the others did not want to try and help Brian, and she was being very loud about it.
#       - Evelyn asked Jade to quiet down and not draw attention, saying that Jade is not being rational.
#       - Marcus is inspecting the layout, seeing if there is a way the party can climb onto the restaurant roof.
#       - Jade insulted Evelyn and picked up a stray wooden baseball bat laying on the ground
#       - Evelyn fired her shotfun at Jade.
#
#
# ==================== END: current_situation ====================
#
# ==================== START: biases_and_habits ====================
#
# Your character's implicit biases and habitual behaviors are tendencies and patterns of behavior that the character exhibits automatically in response to certain situations or stimuli.
# Use these below biases and habits to inform your responses and actions, ensuring that they align with the character's established patterns of behavior.
# When the current situation and environment pose no immediate threat to the character's well-being or objectives, the character is more likely to respond in accordance with
# their implicit biases and habitual behaviors. However, if the current situation and environment do pose a threat, the character may override their
# biases and habits in order to respond more effectively.
# The character's implicit biases and habitual behaviors are provided below.
#
#
#
#
#
# ==================== END: biases_and_habits ====================
#
# ==================== START: backstory_summary ====================
#
# Your character's backstory is a summary of the history and experiences that have shaped the character's identity, beliefs, and motivations within the story world.
# While this may indirectly influence how the character perceives and responds to their current situation and environment, you should use it primarily to
# set tone for the dialog and discriptions of the character's behavior you generate
# The character's backstory is provided below.
#
#
#     Jade grew up in a bustling city, where she learned to fend for herself after being abandoned by her parents.
#     She became a drug addict. When the zombie apocalypse hit,
#     she was able to evade the undead but felt helpless and unable to help others escape dangerous situations. Jade’s life experiences shaped her into a survivor who values freedom and community,
#     often seeking out fellow misfits to create a new family in the post-apocalyptic world.
#
#
# ==================== END: backstory_summary ====================

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

mini_llm = ChatOpenAI(temperature=0.7, model="gpt-4.1-mini")
not_mini_llm = ChatOpenAI(temperature=0.7, model="gpt-4.1")

# %%
import asyncio


messages = [
    SystemMessage(system_prompt),
    HumanMessage("generate a succinct summary of any outcomes and what Jade's next action will be")
]

mini_futures = [mini_llm.ainvoke(messages) for i in range(10)]
not_mini_futures = [not_mini_llm.ainvoke(messages) for i in range(10)]
mini_responses = await asyncio.gather(*mini_futures)
not_mini_responses = await asyncio.gather(*not_mini_futures)

print("GPT 4.1 MINI")
for response in mini_responses:
    print(response.content)
    print("##############################################")

print("##############################################")
print("##############################################")
print("##############################################")
print("GPT 4.1 (NOT MINI)")
for response in not_mini_responses:
    print(response.content)
    print("##############################################")
# Out:
# GPT 4.1 MINI
# Evelyn fired her shotgun at Jade, who was holding a wooden baseball bat and had been loudly confronting the group. The shot likely forces Jade to react defensively. Despite her injured leg, Jade braces herself, gripping the bat tighter, and moves to duck low or sidestep, attempting to avoid the blast and stay ready to counter or defend herself.
# ##############################################
# Evelyn fired her shotgun at Jade, who was holding a wooden baseball bat and limping on her injured left leg. The back alley is enclosed by a locked fence gate, with Marcus examining possible escape routes onto the roof. Tensions in the group are high over whether to search for Brian or find shelter.
#
# Jade tightens her grip on the bat, limps slightly to steady herself, and raises the bat defensively while glaring at Evelyn, preparing to block or counter any further attacks.
# ##############################################
# Evelyn fired her shotgun at Jade, who was holding a wooden bat and limping on an injured, bleeding left leg. Despite the pain and threat, Jade remains defiant and angry about the group's refusal to search for Brian. She readies herself to defend against further aggression, gripping the bat tighter and shifting her weight cautiously to maintain balance despite her injury.
# ##############################################
# Evelyn fired her shotgun at Jade, who is limping on her injured left leg and holding a wooden baseball bat defensively. The shot likely forced Jade to react quickly, increasing her tension with Evelyn. Marcus is preoccupied with scouting an escape route via the restaurant roof.
#
# Jade tightens her grip on the baseball bat and limps closer to the chain-link fence, positioning herself between Evelyn and the padlocked gate, ready to defend herself if Evelyn tries to shoot again or approach. She glares at Evelyn, breathing heavily from pain and exertion.
# ##############################################
# Evelyn fired her shotgun at Jade as Jade angrily wielded the wooden baseball bat, creating a tense and dangerous standoff behind the locked fence. The group remains divided on whether to search for Brian or find safer shelter.
#
# Jade limps forward with resolve despite her injured leg, gripping the baseball bat tightly, preparing to defend herself or confront Evelyn further.
# ##############################################
# Evelyn fired her shotgun at Jade, who raised the wooden baseball bat defensively while limping on her injured left leg. The fence and locked gate still separate them from immediate zombie threats. Marcus is focused on finding an escape route via the restaurant roof.
#
# Jade tightens her grip on the bat, glares at Evelyn, and takes a cautious step back to maintain distance while keeping the bat ready in a defensive stance. She glares defiantly, refusing to back down despite the injury and threat.
# ##############################################
# Evelyn fired her shotgun at Jade, who was holding a wooden baseball bat and visibly injured in her left leg. The shot likely forced Jade to react defensively, but she remains standing despite her limp and bloodied leg. Marcus is preoccupied with scouting escape options.
#
# Jade tightens her grip on the baseball bat, braces herself against the pain in her leg, and prepares to either deflect any further aggression or retaliate if Evelyn advances.
# ##############################################
# Evelyn fired her shotgun at Jade, who was holding the wooden baseball bat and angry at the group. Jade, injured and limping, narrowly avoids the shot and raises the bat defensively. Her next action is to steady herself and prepare to either defend against another attack or retaliate if Evelyn advances.
# ##############################################
# Evelyn fired her shotgun at Jade, who was holding a wooden baseball bat and angry about the group's refusal to search for Brian. Despite Jade’s injured leg and fragile state, the shot forces her to react defensively. Jade raises the bat, preparing to block or counter Evelyn’s attack while limping forward cautiously to maintain distance and readiness.
# ##############################################
# Evelyn fired her shotgun at Jade, who dodges the blast but is forced to brace herself, gripping the wooden baseball bat tightly. Jade limps forward aggressively toward Evelyn, ready to defend herself and challenge Evelyn’s hostility despite her injured leg.
# ##############################################
# ##############################################
# ##############################################
# ##############################################
# GPT 4.1 (NOT MINI)
# Evelyn fired her shotgun at Jade at close range. Given Jade’s injured leg, loud behavior, and lack of cover, Jade is likely hit by the shotgun blast—potentially suffering a serious or incapacitating wound and dropping the wooden bat.
#
# Jade’s next action: Reflexively staggers backward, clutching her wound, collapsing to the ground if unable to remain standing. She makes no immediate offensive move.
# ##############################################
# Evelyn fired her shotgun at Jade, who was holding a wooden baseball bat and limping from a bleeding leg injury. Given Jade’s poor health, limp, and Evelyn firing at close range while Jade’s attention was focused on the argument, Jade is likely struck by the shotgun blast.
#
# Outcome:
# Jade is hit by the shotgun blast, likely dropping the baseball bat and collapsing to the ground, bleeding and further incapacitated.
#
# Next action:
# Jade reflexively tries to shield herself with her arms and, if still conscious, attempts to crawl away or curl up, gasping out in pain.
# ##############################################
# Evelyn fires her shotgun at Jade at close range. Jade, already injured and limping, is hit before she can react. She drops the baseball bat and collapses to the ground, bleeding heavily. Her next action is to instinctively clutch her wounded area, gasping for breath and attempting to crawl away from Evelyn, dragging herself toward the dumpsters for cover.
# ##############################################
# Evelyn fires her shotgun at Jade at close range. With her injured leg and distracted state, Jade cannot dodge. The blast hits Jade, causing her to collapse to the grimy alley ground, bleeding heavily.
#
# Jade’s next action: She drops the baseball bat and instinctively tries to press her hands to her wounds, gasping for breath.
# ##############################################
# Evelyn fires her shotgun at Jade at close range. Given Jade’s injured leg, lack of cover, and the suddenness of the attack, Jade is unable to dodge or defend herself in time. The shotgun blast strikes Jade, inflicting severe trauma and likely rendering her incapacitated or gravely wounded.
#
# Jade’s next action: Jade collapses to the ground, dropping the baseball bat, clutching her wound, and struggling to remain conscious.
# ##############################################
# Evelyn fired her shotgun at Jade at close range. Due to Jade’s injured leg and gaunt frame, she is unable to dodge or defend herself effectively. The shotgun blast hits Jade, likely causing severe injury or incapacitation. Jade drops the baseball bat and collapses to the ground, bleeding heavily and unable to take further purposeful action.
# ##############################################
# Evelyn fires her shotgun at Jade at close range. Given Jade's injured leg, lack of cover, and Evelyn's readiness, Jade cannot dodge. The shotgun blast hits Jade, causing her to collapse, badly wounded and likely incapacitated. Jade drops the baseball bat. Her next action is an involuntary gasp and attempt to cover the wound with her hands, bleeding heavily and unable to rise.
# ##############################################
# Evelyn fired her shotgun at Jade at close range. With her injured leg and being caught off guard, Jade is unable to dodge. The shotgun blast hits her, likely causing severe injury or incapacitation. Jade collapses to the ground, dropping the wooden baseball bat. Her next action is involuntary: she clutches her wound and struggles to remain conscious.
# ##############################################
# Evelyn fires her shotgun at Jade. Jade, already injured and limping, cannot react in time to dodge. The shotgun blast hits Jade at close range, likely causing severe injury or incapacitating her. Jade drops the baseball bat and collapses to the ground, bleeding and possibly unconscious or dead. Jade is unable to take any further action.
# ##############################################
# Evelyn fired her shotgun at Jade after a heated argument. Given Jade’s injured leg and close proximity, she is unlikely to dodge effectively and is struck by the shotgun blast. Jade staggers, drops the bat, and collapses to the ground, bleeding and incapacitated. Her next action is reflexive—clutching her wounds and gasping for breath, unable to retaliate or flee.
# ##############################################

# %%
import asyncio

system_prompt = build_story_character_prompt(
    environment=environment_context,
    reflex=None, #removing reflex section to remove shotgun attack
    situation=situation_context,
    biases=bias_context,
    physical_status=None,
    knowledge=None,
    backstory=backstory_context,
    episodic_memory=None,
)

messages = [
    SystemMessage(system_prompt),
    HumanMessage("generate a succinct summary of any outcomes and what Jade's next action will be")
]

mini_futures = [mini_llm.ainvoke(messages) for i in range(10)]
not_mini_futures = [not_mini_llm.ainvoke(messages) for i in range(10)]
mini_responses = await asyncio.gather(*mini_futures)
not_mini_responses = await asyncio.gather(*not_mini_futures)

print("GPT 4.1 MINI")
for response in mini_responses:
    print(response.content)
    print("##############################################")

print("##############################################")
print("##############################################")
print("##############################################")
print("GPT 4.1 (NOT MINI)")
for response in not_mini_responses:
    print(response.content)
    print("##############################################")
# Out:
# GPT 4.1 MINI
# Jade remains defiant and loud, holding the wooden baseball bat after insulting Evelyn. The group is still divided on whether to search for Brian or find better shelter. Marcus is focused on the possibility of accessing the restaurant roof.
#
# Jade’s next action is to plant her feet firmly, gripping the baseball bat tightly, and insist loudly that they must search for Brian immediately despite the others' objections.
# ##############################################
# The group remains divided over whether to search for Brian or find safer shelter. Evelyn has told Jade to quiet down, but Jade remains defiant and angry, holding the wooden baseball bat. Marcus is focused on checking the restaurant roof for a possible escape or vantage point. Jade’s next action is to keep gripping the baseball bat tightly, limping closer toward the fence gate to inspect the chained padlock while continuing to argue loudly for searching for Brian.
# ##############################################
# Jade remains defiant and loud, holding the wooden baseball bat after insulting Evelyn. The group is tense, with Marcus focused on scouting the roof for escape options. No immediate resolution is reached about searching for Brian.
#
# Jade’s next action is to grip the baseball bat tightly and scan the fence and gate, looking for any weak points or ways to open the chained gate despite her injured leg, determined to push for a search for Brian.
# ##############################################
# The group remains divided over whether to search for Brian or find safer shelter. Evelyn has told Jade to quiet down, but Jade remains angry and vocal, escalating tensions by insulting Evelyn and grabbing a wooden baseball bat. Marcus is focused on finding an escape via the restaurant roof.
#
# Jade, still limping and holding the bat, will continue to loudly argue for searching for Brian, refusing to stay silent, her frustration driving her to challenge the group's caution.
# ##############################################
# The group remains divided, with tension rising after Jade loudly insisted on searching for Brian and insulted Evelyn. Marcus is focused on scouting the area for an escape route via the roof. Jade, still limping from her injured leg, grips the wooden baseball bat tightly, ready to defend or push her point.
#
# Next, Jade will continue to argue for searching for Brian, her voice firm but controlled to avoid attracting unwanted attention, while keeping a wary eye on the fence and surroundings for any approaching threat.
# ##############################################
# The group remains divided, with Jade loudly insisting on searching for Brian despite opposition. Evelyn has asked her to be quiet, and Marcus is focused on checking the surroundings for escape routes. Jade, angry and defiant, grips the wooden baseball bat tightly, ready to defend her stance.
#
# Jade’s next action is to stand her ground near the fence gate, glaring at Evelyn while keeping the bat in a ready position, prepared to challenge anyone who tries to silence her again.
# ##############################################
# Jade remains visibly angry and loud after being told to quiet down, gripping the wooden baseball bat defensively. The group remains divided over searching for Brian or finding shelter. Marcus continues inspecting the surroundings for a rooftop escape route. Evelyn attempts to keep Jade calm.
#
# Jade's next action is to take a few cautious steps closer to the fence gate, limping but steady, and raise the baseball bat as if ready to defend or break the chain lock if needed. She looks toward Marcus and the gate, silently urging movement toward a plan.
# ##############################################
# The group remains divided over whether to search for Brian or find better shelter. Evelyn’s attempt to quiet Jade fails, and tension is rising. Marcus is focused on scouting the rooftop as a potential refuge. Jade, still angry and defiant, grips the wooden baseball bat tightly after insulting Evelyn, preparing herself for any confrontation or threat.
#
# Jade’s next action will be to stand her ground near the fence, watching the group warily while gripping the bat, ready to defend her stance or respond if the argument escalates or if zombies approach.
# ##############################################
# The group remains divided and tense over whether to search for Brian or find better shelter. Evelyn has warned Jade to quiet down, but Jade is still angry and vocal, holding a wooden baseball bat. Marcus is focused on scouting the area for rooftop access.
#
# Jade's next action is to grip the wooden baseball bat firmly and scan the fence and gate area for any weak points or possible ways to breach or climb, preparing to push for searching for Brian despite the group's hesitation.
# ##############################################
# The group remains divided over whether to search for Brian or find better shelter. Jade is visibly angry and vocal about wanting to help Brian, causing tension with Evelyn. Marcus is focused on finding a way onto the restaurant roof. Jade, holding the wooden baseball bat, continues to assert her stance loudly.
#
# Next, Jade will take a few steps toward the fence gate, gripping the bat tightly, and call out to the others sharply, demanding they reconsider and join her in searching for Brian immediately.
# ##############################################
# ##############################################
# ##############################################
# ##############################################
# GPT 4.1 (NOT MINI)
# Jade, limping and visibly angry, holds the baseball bat tightly. After insulting Evelyn for refusing to help Brian, she glares at both companions and moves toward the chain-link fence, scanning for any opening or weakness, prepared to argue further or attempt to leave and search for Brian herself if she finds a way out.
# ##############################################
# Jade, angry and limping from her leg injury, clutches the wooden baseball bat and glares at Evelyn for telling her to quiet down. She ignores the request to be quiet and mutters another insult under her breath. Still fuming, she moves closer to the chained fence gate, scanning the alley for any sign of Brian or approaching zombies, ready to shout again if she thinks she spots anything.
# ##############################################
# Jade, still angry and loudly arguing about searching for Brian, grips the wooden baseball bat and glares at Evelyn. Ignoring Evelyn’s warning to quiet down, Jade limps to the fence gate and rattles the padlock in frustration, scanning the alley to see if there’s any other way out or any sign of Brian. Her next action is to move toward Marcus, pointing with the bat and insisting they need to get back out and look for Brian.
# ##############################################
# Jade, angry at the group's reluctance to help Brian, has picked up a baseball bat and insulted Evelyn. She continues to stand near the others, gripping the bat and glaring at Evelyn, making no move to quiet down. Her next action is to limp a few steps toward the fence, scanning the alley for any sign of Brian or approaching danger while still arguing her point.
# ##############################################
# Jade, limping and clutching the baseball bat, glares at Evelyn but lowers her voice slightly. She scans the alley for threats, frustrated but aware of the need for caution. She moves closer to the fence gate, still tense, and checks the chain and padlock, testing if there’s any slack or weakness. Her next action will be to examine the gate for possible escape or entry points, keeping an eye on her group and surroundings.
# ##############################################
# Jade, still angry and limping from her leg injury, grips the wooden baseball bat tightly and glares at Evelyn. She ignores Evelyn's warning to quiet down, her voice raised as she insists they can't just abandon Brian. Jade stays near the fence, scanning for zombies, but makes no move to leave yet. Her next action is to limp closer to Marcus, calling out for his opinion and urging him to help her figure out a way to get out and search for Brian.
# ##############################################
# Jade, limping and furious, picks up the wooden baseball bat and glares at Evelyn, still defiant about searching for Brian. She keeps her voice low but tense, muttering a final insult under her breath. She shoulders her backpack and moves to stand near the fence gate, scanning the alley for signs of Brian or danger while gripping the bat tightly, ready to react if anything approaches.
# ##############################################
# Jade continues to glare at Evelyn, gripping the baseball bat tightly. She limps toward the chained fence gate, scanning for any sign of Brian or approaching zombies. Ignoring Evelyn’s warning, she raises her voice again, calling Brian’s name into the night.
# ##############################################
# Jade, still limping and angry, grips the baseball bat tightly and glares at Evelyn. She paces near the fence, ignoring Evelyn’s warning to quiet down. She keeps her voice low but tense as she insists they can’t leave Brian behind. Jade scans the courtyard for any way out or clues to Brian’s whereabouts while staying close to the group, ready to argue or act if necessary.
#
# Next action: Jade moves toward the fence gate, inspecting the chain and padlock for weakness or a way to break it open with the bat, intent on finding a way to search for Brian.
# ##############################################
# Jade, angry and limping from her injured leg, stands defensively with the baseball bat after insulting Evelyn. She glances toward the fence and the dark alley beyond, then turns back to the group. Ignoring Evelyn’s request to quiet down, Jade loudly insists they can’t abandon Brian, and begins limping toward the gate to inspect if there’s any way to open or climb it, gripping the bat tightly.
# ##############################################
