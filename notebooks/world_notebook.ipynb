# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage
from models.generations import GameWorldBuilderAgentGeneration

llm = ChatOpenAI(temperature=0.7, model="gpt-4.1").with_structured_output(GameWorldBuilderAgentGeneration)

# %%
import asyncio


messages = [
    SystemMessage(
        """
        You are generating a game world for a intractive narrative to take place within.
        Other LLM generations will iterate on this world, each controlling a single actor (character)
        by generating facts for them.

        The story is about is an active and escalating zombie outbreak.
        The setting is a suburban neighborhood.
        Generate at least five locations within this neighborhood.
            Locations should be things like a buidling interior, or the street, or a park, not a specific room
            Location ids are the name of the location in snake_case format
        Generate three survivor characters that are all strangers forced together. None of them are children.
            Generate interesting characters with unique traits. Do not discuss their determination or resolve or other emotions.
            The characters do not get along well with each other.
            Only provide outwardly observable facts.
            Actor ids are the full name (first and last name) of the character in snake_case format
        Generate at least two zombie characters that are mindless and will pursue and attack any non-zombie actor they encounter.
            These are aggressive, fast zombies, not slow ambling zombies. They will easily break through doors, windows, and barricades.
            These zombies will catch survivors if they are not disposed of quickly.
            Actor ids are the full name (first and last name) of the character in snake_case format. Even zombies have a first and last name.
        Generate some items.
            These may be weapons, tools, backpacks, or anything else that fits the setting.
            Make a few of them held by actors, and a few sitting out in locations
            Item ids are the qualified title of the item in snake_case format.
        Generate one active scenario involving generated characters.
        Generate some history within this scenario so that we are joining in media res.
            Note that there is a game loop that cycles through all actors in a scenario round-robin style.
            So the history within a scenario should reflect this with each actor in turn having outcomes resolved and then responding
        """),
    HumanMessage("Generate a game world according to the above instructions")
]

futures = [llm.ainvoke(messages) for i in range(1)]
responses = await asyncio.gather(*futures)

# %%
import dill

generated = GameWorldBuilderAgentGeneration.model_validate(responses[0])
with open("sandbox/generated_game_world.pkl", "wb") as f:
    dill.dump(generated, f)

# %%
from models.game_state import Episode
from models.game_state import GameWorld
import dill

with open("sandbox/generated_game_world.pkl", "rb") as f:
    generated = dill.load(f)
    
game_world = GameWorld()
game_world.actors = {actor.id: actor for actor in generated.actors}
game_world.locations = {location.id: location for location in generated.locations}
game_world.items = {item.id: item for item in generated.items}

for generated_ep in generated.active_episodes:
    episode = Episode()
    episode.actor_ids = generated_ep.actor_ids
    episode.event_history = generated_ep.event_history
    episode.actor_action_queues = {x.key: x.value for x in generated_ep.actor_action_queues}
    game_world.active_episodes.append(episode)

with open("sandbox/game_world.pkl", "wb") as f:
    dill.dump(game_world, f)

# %%
from devtools import pprint

with open("sandbox/game_world.pkl", "rb") as f:
    game_world = dill.load(f)

pprint(game_world)
# Out:
# GameWorld(
#     locations={
#         LocationId(
#             value='oakridge_cul_de_sac',
#         ): ObservableLocationEntity(
#             facts=[
#                 'A cul-de-sac lined with parked cars and scattered bikes.',
#                 'Broken glass litters the pavement near a toppled mailbox.',
#             ],
#             keywords=[
#                 Keyword(
#                     value='street',
#                 ),
#                 Keyword(
#                     value='open',
#                 ),
#             ],
#             id=LocationId(
#                 value='oakridge_cul_de_sac',
#             ),
#             state_history=[
#                 ObservableLocationState(
#                     facts=[
#                         'Some cars show signs of forced entry.',
#                         'Fresh blood spatters are visible near a storm drain.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='damaged',
#                         ),
#                     ],
#                     condition=<ObservableCondition.DAMAGED: 'DAMAGED'>,
#                 ),
#             ],
#         ),
#         LocationId(
#             value='michaels_family_home',
#         ): ObservableLocationEntity(
#             facts=[
#                 'A single-story house with the front door hanging off its hinges.',
#                 'Family photos are scattered across the entry.',
#             ],
#             keywords=[
#                 Keyword(
#                     value='residential',
#                 ),
#                 Keyword(
#                     value='wrecked',
#                 ),
#             ],
#             id=LocationId(
#                 value='michaels_family_home',
#             ),
#             state_history=[
#                 ObservableLocationState(
#                     facts=[
#                         'Broken furniture and overturned chairs fill the living room.',
#                         'A bloodied trail leads toward the kitchen.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='ransacked',
#                         ),
#                     ],
#                     condition=<ObservableCondition.DAMAGED: 'DAMAGED'>,
#                 ),
#             ],
#         ),
#         LocationId(
#             value='wilson_backyard',
#         ): ObservableLocationEntity(
#             facts=[
#                 'A well-kept backyard enclosed by a wooden fence.',
#                 "Children's toys are scattered across the overgrown grass.",
#             ],
#             keywords=[
#                 Keyword(
#                     value='outdoor',
#                 ),
#             ],
#             id=LocationId(
#                 value='wilson_backyard',
#             ),
#             state_history=[
#                 ObservableLocationState(
#                     facts=[
#                         'One fence panel is broken.',
#                         'A garden shed stands at the far end.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='breached',
#                         ),
#                     ],
#                     condition=<ObservableCondition.DAMAGED: 'DAMAGED'>,
#                 ),
#             ],
#         ),
#         LocationId(
#             value='elmwood_park',
#         ): ObservableLocationEntity(
#             facts=[
#                 'A small park with a rusted playground and a sand pit.',
#                 'Benches are overturned and litter is everywhere.',
#             ],
#             keywords=[
#                 Keyword(
#                     value='public',
#                 ),
#                 Keyword(
#                     value='playground',
#                 ),
#             ],
#             id=LocationId(
#                 value='elmwood_park',
#             ),
#             state_history=[
#                 ObservableLocationState(
#                     facts=[
#                         'A bicycle is abandoned beside the swings.',
#                         'A backpack sits open near the sandbox.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='abandoned',
#                         ),
#                     ],
#                     condition=<ObservableCondition.DAMAGED: 'DAMAGED'>,
#                 ),
#             ],
#         ),
#         LocationId(
#             value='oakridge_convenience_store',
#         ): ObservableLocationEntity(
#             facts=[
#                 'A corner convenience store with smashed windows.',
#                 'Shelves are mostly empty, with some snacks and drinks left behind.',
#             ],
#             keywords=[
#                 Keyword(
#                     value='store',
#                 ),
#                 Keyword(
#                     value='looted',
#                 ),
#             ],
#             id=LocationId(
#                 value='oakridge_convenience_store',
#             ),
#             state_history=[
#                 ObservableLocationState(
#                     facts=[
#                         'Cash register is open and empty.',
#                         'A baseball bat lies behind the counter.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='damaged',
#                         ),
#                     ],
#                     condition=<ObservableCondition.DAMAGED: 'DAMAGED'>,
#                 ),
#             ],
#         ),
#     },
#     actors={
#         ActorId(
#             value='james_foster',
#         ): ObservableActorEntity(
#             facts=[
#                 'A man in his early 30s wearing work boots and a neon orange vest.',
#                 'He has a noticeable limp and carries a battered metal lunchbox.',
#             ],
#             keywords=[
#                 Keyword(
#                     value='survivor',
#                 ),
#                 Keyword(
#                     value='limping',
#                 ),
#                 Keyword(
#                     value='construction',
#                 ),
#             ],
#             id=ActorId(
#                 value='james_foster',
#             ),
#             state_history=[
#                 ObservableActorState(
#                     facts=[
#                         'His jeans are torn and smeared with mud.',
#                         'He grips a crowbar tightly.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='alert',
#                         ),
#                     ],
#                     location_id=LocationId(
#                         value='oakridge_cul_de_sac',
#                     ),
#                     health=<ObservableHealth.FAIR_HEALTH: 'FAIR_HEALTH'>,
#                     arousal=<ObservableArousal.ALERT: 'ALERT'>,
#                     control=<ObservableControl.ASSERTIVE: 'ASSERTIVE'>,
#                     emotion=Keyword(
#                         value='irritated',
#                     ),
#                 ),
#             ],
#         ),
#         ActorId(
#             value='tiffany_cho',
#         ): ObservableActorEntity(
#             facts=[
#                 'A woman in her late 20s with short dyed blue hair and a tattooed forearm.',
#                 'She wears a bike messenger bag and fingerless gloves.',
#             ],
#             keywords=[
#                 Keyword(
#                     value='survivor',
#                 ),
#                 Keyword(
#                     value='tattooed',
#                 ),
#                 Keyword(
#                     value='defensive',
#                 ),
#             ],
#             id=ActorId(
#                 value='tiffany_cho',
#             ),
#             state_history=[
#                 ObservableActorState(
#                     facts=[
#                         'Her shirt is torn at the sleeve.',
#                         'She holds a heavy flashlight.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='tense',
#                         ),
#                     ],
#                     location_id=LocationId(
#                         value='oakridge_cul_de_sac',
#                     ),
#                     health=<ObservableHealth.GOOD_HEALTH: 'GOOD_HEALTH'>,
#                     arousal=<ObservableArousal.INTENSE: 'INTENSE'>,
#                     control=<ObservableControl.ASSERTIVE: 'ASSERTIVE'>,
#                     emotion=Keyword(
#                         value='annoyed',
#                     ),
#                 ),
#             ],
#         ),
#         ActorId(
#             value='michael_barnes',
#         ): ObservableActorEntity(
#             facts=[
#                 'A middle-aged man with thick glasses, balding, and dressed in a wrinkled button-down shirt.',
#                 'He clutches a plastic grocery bag filled with canned goods.',
#             ],
#             keywords=[
#                 Keyword(
#                     value='survivor',
#                 ),
#                 Keyword(
#                     value='nervous',
#                 ),
#                 Keyword(
#                     value='cautious',
#                 ),
#             ],
#             id=ActorId(
#                 value='michael_barnes',
#             ),
#             state_history=[
#                 ObservableActorState(
#                     facts=[
#                         'He keeps glancing over his shoulder.',
#                         'He is unarmed.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='unprepared',
#                         ),
#                     ],
#                     location_id=LocationId(
#                         value='oakridge_cul_de_sac',
#                     ),
#                     health=<ObservableHealth.GOOD_HEALTH: 'GOOD_HEALTH'>,
#                     arousal=<ObservableArousal.ALERT: 'ALERT'>,
#                     control=<ObservableControl.COMPOSED: 'COMPOSED'>,
#                     emotion=Keyword(
#                         value='anxious',
#                     ),
#                 ),
#             ],
#         ),
#         ActorId(
#             value='marcus_evans',
#         ): ObservableActorEntity(
#             facts=[
#                 'A zombie with bloodied hands, wearing a torn soccer uniform.',
#                 'Its jaw hangs at an unnatural angle.',
#             ],
#             keywords=[
#                 Keyword(
#                     value='zombie',
#                 ),
#                 Keyword(
#                     value='aggressive',
#                 ),
#             ],
#             id=ActorId(
#                 value='marcus_evans',
#             ),
#             state_history=[
#                 ObservableActorState(
#                     facts=[
#                         'It moves with jerky, rapid motions.',
#                         'There is a large bite mark on its calf.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='fast',
#                         ),
#                     ],
#                     location_id=LocationId(
#                         value='wilson_backyard',
#                     ),
#                     health=<ObservableHealth.POOR_HEALTH: 'POOR_HEALTH'>,
#                     arousal=<ObservableArousal.INTENSE: 'INTENSE'>,
#                     control=<ObservableControl.DOMINANT: 'DOMINANT'>,
#                     emotion=Keyword(
#                         value='frenzied',
#                     ),
#                 ),
#             ],
#         ),
#         ActorId(
#             value='carla_hernandez',
#         ): ObservableActorEntity(
#             facts=[
#                 'A zombie in a business suit, missing one shoe.',
#                 'Its eyes are clouded and its movements are erratic.',
#             ],
#             keywords=[
#                 Keyword(
#                     value='zombie',
#                 ),
#                 Keyword(
#                     value='feral',
#                 ),
#             ],
#             id=ActorId(
#                 value='carla_hernandez',
#             ),
#             state_history=[
#                 ObservableActorState(
#                     facts=[
#                         'Its left hand is mangled.',
#                         'It has blood smeared across its face.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='fast',
#                         ),
#                     ],
#                     location_id=LocationId(
#                         value='oakridge_convenience_store',
#                     ),
#                     health=<ObservableHealth.POOR_HEALTH: 'POOR_HEALTH'>,
#                     arousal=<ObservableArousal.INTENSE: 'INTENSE'>,
#                     control=<ObservableControl.DOMINANT: 'DOMINANT'>,
#                     emotion=Keyword(
#                         value='ravenous',
#                     ),
#                 ),
#             ],
#         ),
#     },
#     items={
#         ItemId(
#             value='crowbar_james_foster',
#         ): ObservableItemEntity(
#             facts=[
#                 'A sturdy crowbar with paint flecks.',
#             ],
#             keywords=[
#                 Keyword(
#                     value='weapon',
#                 ),
#             ],
#             id=ItemId(
#                 value='crowbar_james_foster',
#             ),
#             state_history=[
#                 ObservableItemState(
#                     facts=[
#                         'The handle is scratched but intact.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='held',
#                         ),
#                     ],
#                     holder_id=ActorId(
#                         value='james_foster',
#                     ),
#                     condition=<ObservableCondition.GOOD_CONDITION: 'GOOD_CONDITION'>,
#                 ),
#             ],
#         ),
#         ItemId(
#             value='flashlight_tiffany_cho',
#         ): ObservableItemEntity(
#             facts=[
#                 'A heavy-duty metal flashlight with some dried blood on the casing.',
#             ],
#             keywords=[
#                 Keyword(
#                     value='tool',
#                 ),
#                 Keyword(
#                     value='blunt',
#                 ),
#             ],
#             id=ItemId(
#                 value='flashlight_tiffany_cho',
#             ),
#             state_history=[
#                 ObservableItemState(
#                     facts=[
#                         'Still works when switched on.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='held',
#                         ),
#                     ],
#                     holder_id=ActorId(
#                         value='tiffany_cho',
#                     ),
#                     condition=<ObservableCondition.GOOD_CONDITION: 'GOOD_CONDITION'>,
#                 ),
#             ],
#         ),
#         ItemId(
#             value='grocery_bag_michael_barnes',
#         ): ObservableItemEntity(
#             facts=[
#                 'A plastic grocery bag containing three cans of green beans and a can opener.',
#             ],
#             keywords=[
#                 Keyword(
#                     value='supplies',
#                 ),
#             ],
#             id=ItemId(
#                 value='grocery_bag_michael_barnes',
#             ),
#             state_history=[
#                 ObservableItemState(
#                     facts=[
#                         'The bag is double-knotted at the top.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='held',
#                         ),
#                     ],
#                     holder_id=ActorId(
#                         value='michael_barnes',
#                     ),
#                     condition=<ObservableCondition.GOOD_CONDITION: 'GOOD_CONDITION'>,
#                 ),
#             ],
#         ),
#         ItemId(
#             value='baseball_bat_oakridge_convenience_store',
#         ): ObservableItemEntity(
#             facts=[
#                 'An aluminum baseball bat with a cracked handle.',
#             ],
#             keywords=[
#                 Keyword(
#                     value='weapon',
#                 ),
#             ],
#             id=ItemId(
#                 value='baseball_bat_oakridge_convenience_store',
#             ),
#             state_history=[
#                 ObservableItemState(
#                     facts=[
#                         'Lying behind the store counter.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='unclaimed',
#                         ),
#                     ],
#                     holder_id=ActorId(
#                         value='oakridge_convenience_store',
#                     ),
#                     condition=<ObservableCondition.DAMAGED: 'DAMAGED'>,
#                 ),
#             ],
#         ),
#         ItemId(
#             value='green_backpack_elmwood_park',
#         ): ObservableItemEntity(
#             facts=[
#                 'A green backpack with a water bottle in the side pouch.',
#             ],
#             keywords=[
#                 Keyword(
#                     value='item',
#                 ),
#                 Keyword(
#                     value='bag',
#                 ),
#             ],
#             id=ItemId(
#                 value='green_backpack_elmwood_park',
#             ),
#             state_history=[
#                 ObservableItemState(
#                     facts=[
#                         'Sits open near the sandbox.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='unclaimed',
#                         ),
#                     ],
#                     holder_id=ActorId(
#                         value='elmwood_park',
#                     ),
#                     condition=<ObservableCondition.GOOD_CONDITION: 'GOOD_CONDITION'>,
#                 ),
#             ],
#         ),
#     },
#     active_episodes=[
#         Episode(
#             actor_ids=[
#                 ActorId(
#                     value='james_foster',
#                 ),
#                 ActorId(
#                     value='tiffany_cho',
#                 ),
#                 ActorId(
#                     value='michael_barnes',
#                 ),
#                 ActorId(
#                     value='marcus_evans',
#                 ),
#             ],
#             event_history=[
#                 ObservableEvent(
#                     facts=[
#                         (
#                             'The sound of breaking glass echoed from the Wilson backyard, drawing the attention of nea'
#                             'rby zombies.'
#                         ),
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='noise',
#                         ),
#                     ],
#                     location_id=LocationId(
#                         value='wilson_backyard',
#                     ),
#                     source_entity_ids=[
#                         LocationId(
#                             value='wilson_backyard',
#                         ),
#                     ],
#                     impacted_actor_ids=[
#                         ActorId(
#                             value='marcus_evans',
#                         ),
#                     ],
#                     impacted_item_ids=[],
#                 ),
#                 ObservableAction(
#                     facts=[
#                         'James Foster used his crowbar to pry open a jammed car door, looking for supplies.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='search',
#                         ),
#                     ],
#                     location_id=LocationId(
#                         value='oakridge_cul_de_sac',
#                     ),
#                     source_actor_ids=[
#                         ActorId(
#                             value='james_foster',
#                         ),
#                     ],
#                     target_actor_ids=[],
#                     target_item_ids=[],
#                 ),
#                 ObservableAction(
#                     facts=[
#                         'Tiffany Cho yelled at James for making too much noise, clutching her flashlight tightly.',
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='shout',
#                         ),
#                     ],
#                     location_id=LocationId(
#                         value='oakridge_cul_de_sac',
#                     ),
#                     source_actor_ids=[
#                         ActorId(
#                             value='tiffany_cho',
#                         ),
#                     ],
#                     target_actor_ids=[
#                         ActorId(
#                             value='james_foster',
#                         ),
#                     ],
#                     target_item_ids=[],
#                 ),
#                 ObservableAction(
#                     facts=[
#                         (
#                             'Michael Barnes tried to quietly move away from the commotion, edging toward a nearby hedg'
#                             'e.'
#                         ),
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='sneak',
#                         ),
#                     ],
#                     location_id=LocationId(
#                         value='oakridge_cul_de_sac',
#                     ),
#                     source_actor_ids=[
#                         ActorId(
#                             value='michael_barnes',
#                         ),
#                     ],
#                     target_actor_ids=[],
#                     target_item_ids=[],
#                 ),
#                 ObservableAction(
#                     facts=[
#                         (
#                             'Marcus Evans, the zombie, burst through the broken fence into the cul-de-sac, drawn by th'
#                             'e noise.'
#                         ),
#                     ],
#                     keywords=[
#                         Keyword(
#                             value='attack',
#                         ),
#                         Keyword(
#                             value='pursue',
#                         ),
#                     ],
#                     location_id=LocationId(
#                         value='oakridge_cul_de_sac',
#                     ),
#                     source_actor_ids=[
#                         ActorId(
#                             value='marcus_evans',
#                         ),
#                     ],
#                     target_actor_ids=[
#                         ActorId(
#                             value='james_foster',
#                         ),
#                         ActorId(
#                             value='tiffany_cho',
#                         ),
#                         ActorId(
#                             value='michael_barnes',
#                         ),
#                     ],
#                     target_item_ids=[],
#                 ),
#             ],
#             actor_action_queues={},
#         ),
#     ],
# )
